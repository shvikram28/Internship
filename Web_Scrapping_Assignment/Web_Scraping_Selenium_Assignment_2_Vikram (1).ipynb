# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.

# %%
# lets connect to the web driver first
driver=webdriver.Chrome(r"C:\Users\Vikram19c\Downloads\chromedriver.exe")

# %%
#opening the naukri page on automated chrome browser
driver.get(' https://www.naukri.com/')

# %%
# entering designation 

designation1=driver.find_element(By.CLASS_NAME, 'suggestor-input')
designation1.send_keys('Data Analyst')

# %%
#entering location

location1=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location1.send_keys('Banglore')

# %%
# entering search button

search1=driver.find_element(By.CLASS_NAME, 'qsbSubmit')
search1.click()

# %%
job_title1=[]
job_location1=[]
company_name1=[]
experience_required1=[]

# %%
# scraping job titles from the given page
title_tags=driver.find_elements(By.XPATH, '//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title1.append(title)
    
# scraping job location from the given page
location_tags=driver.find_elements(By.XPATH, '//span[@title="Bangalore/Bengaluru "]')
for i in location_tags[0:10]:
    location=i.text
    job_location1.append(location)
    
# scraping company name from the given page
company_tags=driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name1.append(company)

# scraping job experience from the given page
experience_tags=driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required1.append(experience)

# %%
print(len(job_title1), len(job_location1), len(company_name1), len(experience_required1))
# Out:
# 10 10 10 10

# %%
import pandas as pd

# %%
# creating Data Frame

df=pd.DataFrame({'Title':job_title1, 'location':job_location1, 'company':company_name1, 'experience':experience_required1})
df
# Out:
#                                        Title             location  \
# 0       Data Analysts with Business Analysis  Bangalore/Bengaluru
# 1  Immediate Hiring For MIS and Data Analyst  Bangalore/Bengaluru
# 2                        Junior Data Analyst  Bangalore/Bengaluru
# 3                      Customer Data Analyst  Bangalore/Bengaluru
# 4  Business Data Analysts (People & Culture)  Bangalore/Bengaluru
# 5                   Senior Data Analyst - DC  Bangalore/Bengaluru
# 6                               Data Analyst  Bangalore/Bengaluru
# 7                               Data Analyst  Bangalore/Bengaluru
# 8                           Data Analyst- II  Bangalore/Bengaluru
# 9      Manager/Senior Manager - Data Analyst  Bangalore/Bengaluru
#
#                       company experience
# 0                Avanze Group    6-8 Yrs
# 1                     Regalix    1-6 Yrs
# 2                        RCPC    0-1 Yrs
# 3                      Oracle    1-4 Yrs
# ...

# %% [markdown]
# # Q2:Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.

# %%
# lets connect to the web driver first
driver=webdriver.Chrome(r"C:\Users\Vikram19c\Downloads\chromedriver.exe")

# %%
#opening the naukri page on automated chrome browser
driver.get('https://www.naukri.com/')

# %%
# entering designation 

designation1=driver.find_element(By.CLASS_NAME, 'suggestor-input')
designation1.send_keys('Data Scientist')

# %%
#entering location

location1=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location1.send_keys('Banglore')

# %%
# entering search button

search1=driver.find_element(By.CLASS_NAME, 'qsbSubmit')
search1.click()

# %%
job_title2=[]
job_location2=[]
company_name2=[]

# %%
# scraping job titles from the given page
title_tags1=driver.find_elements(By.XPATH, '//a[@class="title ellipsis"]')
for i in title_tags1[0:10]:
    title1=i.text
    job_title2.append(title1)
    
# scraping job location from the given page
location_tags1=driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft locWdth"]')
for i in location_tags1[0:10]:
    location1=i.text
    job_location2.append(location1)
    
# scraping company name from the given page
company_tags1=driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in company_tags1[0:10]:
    company1=i.text
    company_name2.append(company1)

# %%
print(len(job_title2), len(job_location2), len(company_name2))
# Out:
# 10 10 10

# %%
import pandas as pd

# %%
# creating Data Frame

df=pd.DataFrame({'Title':job_title2, 'location':job_location2, 'company':company_name2})
df
# Out:
#                                                Title  \
# 0                                     Data Scientist
# 1                            Data Science Specialist
# 2                   Analystics & Modeling Specialist
# 3                                Lead Data Scientist
# 4                                     Data Scientist
# 5                     Data Scientist Knowledge graph
# 6                                     Data Scientist
# 7                             Analytic Delivery Lead
# 8  Opportunity For Data Scientist/Sr. Data Scient...
# 9                      Supply Chain Specialist Staff
#
#                                             location             company
# 0  Temp. WFH - Hyderabad/Secunderabad, Pune, Chen...       Tech Mahindra
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...           Accenture
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...           Accenture
# 3  Noida, Hyderabad/Secunderabad, Pune, Chennai, ...           Birlasoft
# ...

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage as shown below: You have to use the location and salary filter. You have to scrape data for “Data Scientist” designation for first 10 job results. You have to scrape the job-title, job-location, company name, experience required.The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

# %%
# lets connect to the web driver first
driver=webdriver.Chrome(r"C:\Users\Vikram19c\Downloads\chromedriver.exe")

# %%
#opening the naukri page on automated chrome browser
driver.get('https://www.naukri.com/')

# %%
# entering designation 

designation1=driver.find_element(By.CLASS_NAME, 'suggestor-input')
designation1.send_keys('Data Scientist')

# %%
# entering search button

search1=driver.find_element(By.CLASS_NAME, 'qsbSubmit')
search1.click()

# %%
job_title3=[]
job_location3=[]
company_name3=[]
experience_required3=[]

# %%
# scraping job titles from the given page
title_tags2=driver.find_elements(By.XPATH, '//a[@class="title ellipsis"]')
for i in title_tags2[0:10]:
    title2=i.text
    job_title3.append(title2)
    
# scraping job location from the given page
location_tags2=driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft locWdth"]')
for i in location_tags2[0:10]:
    location2=i.text
    job_location3.append(location2)
    
# scraping company name from the given page
company_tags2=driver.find_elements(By.XPATH, '//a[@class="subTitle ellipsis fleft"]')
for i in company_tags2[0:10]:
    company2=i.text
    company_name3.append(company2)

# scraping job experience from the given page
experience_tags2=driver.find_elements(By.XPATH, '//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags2[0:10]:
    experience2=i.text
    experience_required3.append(experience2)

# %%
print(len(job_title3), len(job_location3), len(company_name3), len(experience_required3))
# Out:
# 10 10 10 10

# %%
import pandas as pd

# %%
# creating Data Frame

df=pd.DataFrame({'Title':job_title3, 'location':job_location3, 'company':company_name3, 'experience': experience_required3})
df
# Out:
#                                         Title  \
# 0                        Analyst-Data Science
# 1                              Data Scientist
# 2                              Data Scientist
# 3                       SE/SSE-Data Scientist
# 4               Occupancy Surveyor - Gurugram
# 5                              Data Scientist
# 6  AWS Data Warehouse Developer - IT Industry
# 7                                     Modeler
# 8                    Associate Data Scientist
# 9                              Data Scientist
#
#                                             location  \
# 0                                   Gurgaon/Gurugram
# 1  Delhi / NCR, Noida(Sector-136 Noida), Ghaziaba...
# 2                                              Noida
# 3                                        Delhi / NCR
# 4                                   Gurgaon/Gurugram
# 5  Dehradun, Hyderabad/Secunderabad, Gurgaon/Guru...
# 6      Delhi / NCR, Bangalore/Bengaluru, Maharashtra
# ...

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes: 1. Brand 2. ProductDescriptio 3. Price. The attributes which you have to scrape is ticked marked in the below image.

# %%
# lets connect to the web driver first
driver=webdriver.Chrome(r"C:\Users\Vikram19c\Downloads\chromedriver.exe")

# %%
#opening the flipkart page on automated chrome browser
driver.get('https://www.flipkart.com/')

# %%
# entering product name 

product=driver.find_element(By.CLASS_NAME, '_3704LK')
product.send_keys('sunglasses')

# %%
# entering search button

search=driver.find_element(By.CLASS_NAME, 'L0Z3Pu')
search.click()

# %%
Brand_name=[]
Product_description=[]
Prices=[]
Discounts=[]

# %%
# scraping Band name from the first page first 40 products
Brand_tags=driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
for i in Brand_tags[0:40]:
    Brands=i.text
    Brand_name.append(Brands)
    
# scraping Product description from the first page
Product_tags=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
for i in Product_tags[0:40]:
    Products=i.text
    Product_description.append(Products)
    
# scraping prices from the first page
Price_tags=driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]')
for i in Price_tags[0:40]:
    PriceP=i.text
    Prices.append(PriceP)

# scraping Discounts from the first page
Discount_tags=driver.find_elements(By.XPATH, '//div[@class="_3Ay6Sb"]')
for i in Discount_tags[0:40]:
    Discounted=i.text
    Discounts.append(Discounted)

# %%
print(len(Brand_name), len(Product_description), len(Prices), len(Discounts))
# Out:
# 40 40 40 40

# %%
import pandas as pd

# %%
# creating Data Frame for the first page

df=pd.DataFrame({'Brand':Brand_name, 'Product':Product_description, 'Price':Prices, 'Discount': Discounts})
df
# Out:
#             Brand                                            Product   Price  \
# 0       ROYAL SON  UV Protection, Gradient Butterfly Sunglasses (62)    ₹699
# 1          SUNBEE       UV Protection Cat-eye Sunglasses (Free Size)    ₹129
# 2          AISLIN  UV Protection, Gradient Round, Cat-eye Sunglas...    ₹485
# 3   VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...    ₹999
# 4      IZAAN MART           Night Vision Rectangular Sunglasses (55)    ₹290
# 5         Urbanic                 Others Oval Sunglasses (Free Size)    ₹519
# 6         Urbanic                 Others Oval Sunglasses (Free Size)    ₹359
# 7       ROYAL SON  UV Protection, Gradient Butterfly Sunglasses (62)    ₹699
# 8          AISLIN  UV Protection Butterfly, Retro Square Sunglass...    ₹490
# 9       ROYAL SON  Gradient, UV Protection Round, Oval, Cat-eye S...    ₹664
# 10         FOSSIL                        Others Oval Sunglasses (56)  ₹4,819
# ...

# %%
# lets connect to the web driver first
driver=webdriver.Chrome(r"C:\Users\Vikram19c\Downloads\chromedriver.exe")

# %%
#opening the flipkart page on automated chrome browser
driver.get('https://www.flipkart.com/')

# %%
# entering Next button for page 2

Next_button=driver.find_element(By.CLASS_NAME, '_1LKTO3')
Next_button.click()

# %%
Brand_name2=[]
Product_description2=[]
Prices2=[]
Discounts2=[]

# %%
# scraping Brand name from the second page next forty products
Brand_tags2=driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
for i in Brand_tags2[40:80]:
    Brands2=i.text
    Brand_name2.append(Brands2)
    
# scraping Product description from the second page
Product_tags2=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
for i in Product_tags2[40:80]:
    Products2=i.text
    Product_description2.append(Products2)
    
# scraping prices from the second page
Price_tags2=driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]')
for i in Price_tags2[40:80]:
    PriceP2=i.text
    Prices2.append(PriceP2)

# scraping Discounts from the second page
Discount_tags2=driver.find_elements(By.XPATH, '//div[@class="_3Ay6Sb"]')
for i in Discount_tags2[40:80]:
    Discounted2=i.text
    Discounts2.append(Discounted2)

# %%
print(len(Brand_name2), len(Product_description2), len(Prices2), len(Discounts2))
# Out:
# 40 40 40 40

# %%
import pandas as pd

# %%
# creating Data Frame for the second page

df=pd.DataFrame({'Brand':Brand_name2, 'Product':Product_description2, 'Price':Prices2, 'Discount': Discounts2})
df
# Out:
#              Brand                                            Product   Price  \
# 0        Elligator    UV Protection Aviator, Wayfarer Sunglasses (54)    ₹149
# 1           PIRASO          UV Protection Rectangular Sunglasses (52)    ₹218
# 2   kingsunglasses   UV Protection Rectangular Sunglasses (Free Size)    ₹196
# 3           PIRASO           UV Protection Over-sized Sunglasses (65)    ₹391
# 4         Fastrack              UV Protection Aviator Sunglasses (57)    ₹519
# 5    VINCENT CHASE  by Lenskart Polarized, UV Protection Rectangul...    ₹679
# 6        Elligator                UV Protection Round Sunglasses (53)    ₹149
# 7         Fastrack                UV Protection Round Sunglasses (55)    ₹849
# 8        Elligator  Others Cat-eye, Retro Square, Wayfarer Sunglas...    ₹149
# 9        Elligator             UV Protection Wayfarer Sunglasses (53)    ₹179
# 10          PIRASO             UV Protection Wayfarer Sunglasses (32)    ₹245
# ...

# %%
# lets connect to the web driver first
driver=webdriver.Chrome(r"C:\Users\Vikram19c\Downloads\chromedriver.exe")

# %%
# entering Next button for page 3

Next_button3=driver.find_element(By.CLASS_NAME, '_1LKTO3')
Next_button3.click()

# %%
Brand_name3=[]
Product_description3=[]
Prices3=[]
Discounts3=[]

# %%
# scraping Brand name from the third page next 20 products
Brand_tags3=driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
for i in Brand_tags3[0:20]:
    Brands3=i.text
    Brand_name3.append(Brands3)
    
# scraping Product description from the third page next 20 products
Product_tags3=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
for i in Product_tags3[0:20]:
    Products3=i.text
    Product_description3.append(Products3)
    
# scraping prices from the third page
Price_tags3=driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]')
for i in Price_tags3[0:20]:
    PriceP3=i.text
    Prices3.append(PriceP3)

# scraping Discounts from the third page
Discount_tags3=driver.find_elements(By.XPATH, '//div[@class="_3Ay6Sb"]')
for i in Discount_tags3[0:20]:
    Discounted3=i.text
    Discounts3.append(Discounted3)

# %%
print(len(Brand_name3), len(Product_description3), len(Prices3), len(Discounts3))
# Out:
# 20 20 20 20

# %%
# creating Data Frame for the third page

df=pd.DataFrame({'Brand':Brand_name3, 'Product':Product_description3, 'Price':Prices3, 'Discount': Discounts3})
df
# Out:
#                 Brand                                            Product  \
# 0           Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 1            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 2            Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 3          PHENOMENAL         UV Protection Retro Square Sunglasses (53)
# 4           Elligator                UV Protection Round Sunglasses (54)
# 5           Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 6                SRPM             UV Protection Wayfarer Sunglasses (50)
# 7            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 8            Fastrack       UV Protection Aviator Sunglasses (Free Size)
# 9                SRPM  Night Vision, UV Protection Round Sunglasses (54)
# 10         LIZA ANGEL  Riding Glasses, Night Vision Spectacle Sunglas...
# 11      VINCENT CHASE             UV Protection Wayfarer Sunglasses (59)
# ...

# %%
# scrapping Brand Name for the Sunglasses

Brand_Name4=[]

start=0
end=3
for page in range(start,end):
    Brand4=driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
    for i in Brand4[0:100]:
        Brand_Name4.append(i.text)

Brand_Name4
# Out:
# ['Fly Buy',
#  'Resist',
#  'Elligator',
#  'Fastrack',
#  'Fastrack',
#  'PHENOMENAL',
#  'Elligator',
#  'ROZZETTA CRAFT',
#  'Elligator',
#  'Fastrack',
#  'SRPM',
#  'Silver Kartz',
#  'VINCENT CHASE',
#  'Fastrack',
#  'LIZA ANGEL',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'Fastrack',
#  'New Specs',
#  'I Flash',
#  'SRPM',
#  'Elligator',
#  'LIZA ANGEL',
#  'ROZZETTA CRAFT',
#  'kingsunglasses',
#  'EYELLUSION',
#  'SUNBEE',
#  'Fly Buy',
#  'PIRASO',
#  'PIRASO',
#  'New Specs',
#  'Dervin',
#  'SHAAH COLLECTIONS',
#  'PIRASO',
#  'Sewell',
#  'ROZZETTA CRAFT',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'Satyam Kraft',
#  'I Flash',
#  'Fly Buy',
#  'Resist',
#  'Elligator',
#  'Fastrack',
#  'Fastrack',
#  'PHENOMENAL',
#  'Elligator',
#  'ROZZETTA CRAFT',
#  'Elligator',
#  'Fastrack',
#  'SRPM',
#  'Silver Kartz',
#  'VINCENT CHASE',
#  'Fastrack',
#  'LIZA ANGEL',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'Fastrack',
#  'New Specs',
#  'I Flash',
#  'SRPM',
#  'Elligator',
# ...

# %%
# scrapping Product Description for the Sunglasses
Product_description4=[]

start=0
end=3
for page in range(start,end):
    Product4=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
    for i in Product4[0:100]:
        Product_description4.append(i.text)

Product_description4
# Out:
# ['UV Protection Rectangular Sunglasses (Free Size)',
#  'Polarized Wayfarer Sunglasses (Free Size)',
#  'UV Protection Cat-eye, Retro Square, Oval, Round Sungla...',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Retro Square Sunglasses (53)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (55)',
#  'UV Protection Cat-eye, Retro Square, Oval, Round Sungla...',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (50)',
#  'UV Protection Aviator Sunglasses (88)',
#  'UV Protection Wayfarer Sunglasses (59)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'Riding Glasses, Night Vision Spectacle Sunglasses (Fre...',
#  'UV Protection, Gradient Round Sunglasses (Free Size)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Shield Sunglasses (Free Size)',
# ...

# %%
# scrapping Prices for the Sunglasses
Prices4=[]

start=0
end=3
for page in range(start,end):
    Price4=driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]')
    for i in Price4[0:100]:
        Prices4.append(i.text)

Prices4
# Out:
# ['₹399',
#  '₹1,399',
#  '₹149',
#  '₹599',
#  '₹499',
#  '₹129',
#  '₹229',
#  '₹649',
#  '₹129',
#  '₹579',
#  '₹149',
#  '₹266',
#  '₹599',
#  '₹519',
#  '₹174',
#  '₹399',
#  '₹579',
#  '₹579',
#  '₹259',
#  '₹299',
#  '₹179',
#  '₹149',
#  '₹129',
#  '₹399',
#  '₹129',
#  '₹281',
#  '₹185',
#  '₹248',
#  '₹257',
#  '₹244',
#  '₹129',
#  '₹224',
#  '₹185',
#  '₹313',
#  '₹280',
#  '₹399',
#  '₹499',
#  '₹519',
#  '₹299',
#  '₹207',
#  '₹399',
#  '₹1,399',
#  '₹149',
#  '₹599',
#  '₹499',
#  '₹129',
#  '₹229',
#  '₹649',
#  '₹129',
#  '₹579',
#  '₹149',
#  '₹266',
#  '₹599',
#  '₹519',
#  '₹174',
#  '₹399',
#  '₹579',
#  '₹579',
#  '₹259',
#  '₹299',
#  '₹179',
#  '₹149',
#  '₹129',
#  '₹399',
#  '₹129',
#  '₹281',
#  '₹185',
#  '₹248',
#  '₹257',
#  '₹244',
#  '₹129',
#  '₹224',
#  '₹185',
#  '₹313',
#  '₹280',
#  '₹399',
#  '₹499',
#  '₹519',
#  '₹299',
#  '₹207',
#  '₹399',
#  '₹1,399',
#  '₹149',
#  '₹599',
#  '₹499',
#  '₹129',
#  '₹229',
#  '₹649',
#  '₹129',
#  '₹579',
# ...

# %%
# scrapping Discounts for the Sunglasses

Discounts4=[]

start=0
end=3
for page in range(start,end):
    Discount4=driver.find_elements(By.XPATH, '//div[@class="_3Ay6Sb"]')
    for i in Discount4[0:100]:
        Discounts4.append(i.text)

Discounts4
# Out:
# ['42% off',
#  '65% off',
#  '75% off',
#  '40% off',
#  '37% off',
#  '87% off',
#  '90% off',
#  '74% off',
#  '87% off',
#  '35% off',
#  '88% off',
#  '77% off',
#  '70% off',
#  '35% off',
#  '82% off',
#  '80% off',
#  '35% off',
#  '35% off',
#  '90% off',
#  '85% off',
#  '82% off',
#  '85% off',
#  '87% off',
#  '80% off',
#  '87% off',
#  '87% off',
#  '81% off',
#  '44% off',
#  '83% off',
#  '84% off',
#  '87% off',
#  '85% off',
#  '89% off',
#  '87% off',
#  '81% off',
#  '80% off',
#  '75% off',
#  '35% off',
#  '75% off',
#  '79% off',
#  '42% off',
#  '65% off',
#  '75% off',
#  '40% off',
#  '37% off',
#  '87% off',
#  '90% off',
#  '74% off',
#  '87% off',
#  '35% off',
#  '88% off',
#  '77% off',
#  '70% off',
#  '35% off',
#  '82% off',
#  '80% off',
#  '35% off',
#  '35% off',
#  '90% off',
#  '85% off',
#  '82% off',
#  '85% off',
#  '87% off',
#  '80% off',
#  '87% off',
#  '87% off',
#  '81% off',
#  '44% off',
#  '83% off',
#  '84% off',
#  '87% off',
# ...

# %%
print(len(Brand_Name4), len(Product_description4), len(Prices4), len(Discounts4))
# Out:
# 120 120 120 120

# %%
# creating Data Frame for the Sunglasses 

df=pd.DataFrame({'Brand':Brand_Name4, 'Product':Product_description4, 'Price':Prices4, 'Discount': Discounts4})
df
# Out:
#               Brand                                            Product  \
# 0           Fly Buy   UV Protection Rectangular Sunglasses (Free Size)
# 1            Resist          Polarized Wayfarer Sunglasses (Free Size)
# 2         Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 3          Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 4          Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# ..              ...                                                ...
# 115  ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...
# 116  ROZZETTA CRAFT  Polarized, Riding Glasses Sports, Wrap-around ...
# 117        Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...
# 118    Satyam Kraft            Others Spectacle Sunglasses (Free Size)
# 119         I Flash        Gradient Rectangular Sunglasses (Free Size)
#
#       Price Discount
# 0      ₹399  42% off
# 1    ₹1,399  65% off
# 2      ₹149  75% off
# 3      ₹599  40% off
# ...

# %% [markdown]
# # Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
# lets connect to the web driver first
driver=webdriver.Chrome(r"C:\Users\Vikram19c\Downloads\chromedriver.exe")

# %%
#opening the Flipkart page on automated chrome browser
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market')

# %%
# scrapping Rating for the iphone-11

ProductRating=[]

start=0
end=10
for page in range(start,end):
    rat=driver.find_elements(By.XPATH, '//div[@class="_3LWZlK _1BLPMq"]')
    for i in rat:
        ProductRating.append(i.text)

ProductRating
# Out:
# ['5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4']

# %%
# scrapping Review Summary for the iphone-11

ReviewSummary=[]

start=0
end=10
for page in range(start,end):
    Review=driver.find_elements(By.XPATH, '//p[@class="_2-N8zT"]')
    for i in Review:
        ReviewSummary.append(i.text)

ReviewSummary
# Out:
# ['Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Highly recommended',
#  'Worth every penny',
#  'Perfect product!',
#  'Highly recommended',
#  'Great product',
#  'Pretty good',
#  'Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Highly recommended',
#  'Worth every penny',
#  'Perfect product!',
#  'Highly recommended',
#  'Great product',
#  'Pretty good',
#  'Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Highly recommended',
#  'Worth every penny',
#  'Perfect product!',
#  'Highly recommended',
#  'Great product',
#  'Pretty good',
#  'Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Highly recommended',
#  'Worth every penny',
#  'Perfect product!',
#  'Highly recommended',
#  'Great product',
#  'Pretty good',
#  'Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
# ...

# %%
# scrapping Full Review for the iphone-11

FullReview=[]

start=0
end=10
for page in range(start,end):
    Full=driver.find_elements(By.XPATH, '//div[@class="row"]')
    for i in Full[0:100]:
        FullReview.append(i.text)

FullReview
# Out:
# ['4.6★',
#  '5\nSimply awesome',
#  'Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.',
#  'Flipkart Customer\nCertified Buyer, Mokokchung\nNov, 2020',
#  '302453885',
#  '5\nPerfect product!',
#  'Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .',
#  'Flipkart Customer\nCertified Buyer, Hyderabad\nJun, 2020',
#  '222892981',
#  '5\nBest in the market!',
# ...

# %%
print(len(ProductRating),len(ReviewSummary),len(FullReview[0:100]))
# Out:
# 100 100 100

# %%
# creating Data Frame for sneakers

df=pd.DataFrame({'PRODUCT RATINGS':ProductRating, 'Review':ReviewSummary, 'Full Review':FullReview[0:100]})
df
# Out:
#    PRODUCT RATINGS               Review  \
# 0                5       Simply awesome
# 1                5     Perfect product!
# 2                5  Best in the market!
# 3                4      Value-for-money
# 4                5   Highly recommended
# ..             ...                  ...
# 95               5    Worth every penny
# 96               5     Perfect product!
# 97               5   Highly recommended
# 98               5        Great product
# 99               4          Pretty good
#
#                                           Full Review
# 0                                                4.6★
# 1                                   5\nSimply awesome
# 2   Really satisfied with the Product I received.....
# 3   Flipkart Customer\nCertified Buyer, Mokokchung...
# 4                                           302453885
# ..                                                ...
# 95  Manish Raghuvanshi\nCertified Buyer, Hazaribag...
# ...

# %% [markdown]
# # Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
# lets connect to the web driver first
driver=webdriver.Chrome(r"C:\Users\Vikram19c\Downloads\chromedriver.exe")

# %%
#opening the flipkart page on automated chrome browser
driver.get('https://www.flipkart.com/')

# %%
# entering product name Sneaker

product=driver.find_element(By.CLASS_NAME, '_3704LK')
product.send_keys('sneakers')

# %%
# entering search button

search=driver.find_element(By.CLASS_NAME, 'L0Z3Pu')
search.click()

# %%
# scrapping Brand Name for the sneakers

Brand_Name5=[]

start=0
end=3
for page in range(start,end):
    Brand5=driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
    for i in Brand5[0:100]:
        Brand_Name5.append(i.text)

Brand_Name5
# Out:
# ['RapidBox',
#  'SFR',
#  'World Wear Footwear',
#  'aadi',
#  'Kzaara',
#  'ADIDAS',
#  'aadi',
#  'BRUTON',
#  'HRX by Hrithik Roshan',
#  'Kzaara',
#  'RED TAPE',
#  'edisson',
#  'RED TAPE',
#  'PUMA',
#  'World Wear Footwear',
#  'Layasa',
#  'Layasa',
#  'Asian Shoes',
#  'PUMA',
#  'BRUTON',
#  'SFR',
#  'Kzaara',
#  'BIRDE',
#  'BRUTON',
#  'ADIDAS',
#  'Sparx',
#  'Deals4you',
#  'RapidBox',
#  'Layasa',
#  'Layasa',
#  'PUMA',
#  'BRUTON',
#  'Asian Shoes',
#  'PUMA',
#  'U.S. POLO ASSN.',
#  'aadi',
#  'PUMA',
#  'aadi',
#  'PUMA',
#  'BRUTON',
#  'RapidBox',
#  'SFR',
#  'World Wear Footwear',
#  'aadi',
#  'Kzaara',
#  'ADIDAS',
#  'aadi',
#  'BRUTON',
#  'HRX by Hrithik Roshan',
#  'Kzaara',
#  'RED TAPE',
#  'edisson',
#  'RED TAPE',
#  'PUMA',
#  'World Wear Footwear',
#  'Layasa',
#  'Layasa',
#  'Asian Shoes',
#  'PUMA',
#  'BRUTON',
#  'SFR',
#  'Kzaara',
#  'BIRDE',
#  'BRUTON',
#  'ADIDAS',
#  'Sparx',
#  'Deals4you',
#  'RapidBox',
#  'Layasa',
#  'Layasa',
# ...

# %%
# scrapping Product Description for the sneakers
Product_description5=[]

start=0
end=3
for page in range(start,end):
    Product5=driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
    for i in Product5:
        Product_description5.append(i.text)

Product_description5
# Out:
# ['2006 Trenddy Fashion Sporty Casuals Sneakers Running Sh...',
#  '5011-Latest Collection Stylish & Trendy Casual Sneakers...',
#  'Mesh |Lightweight|Comfort|Summer|Trendy|Walking|Outdoor...',
#  'Sneakers For Men',
#  'STREET ICON M Sneakers For Men',
#  'Synthetic Leather |Lightweight|Comfort|Summer|Trendy|Wa...',
#  'Modern Trendy Sneakers Shoes Sneakers For Men',
#  'ACTIVE RUN Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  "001-Original Luxury Branded Fashionable Men's Casual Sn...",
#  'Sneakers For Men',
#  'Neptune Sneakers For Men',
#  'Latest Collection-1216 Stylish Casual Sports Sneakers F...',
#  'Sneakers For Women',
#  'Sneakers For Women',
#  'Future-04 casual shoes for men | Latest Stylish Casual ...',
#  'x 1DER Jack V2 Sneakers For Men',
#  'Modern Trendy Sneakers Shoes Sneakers For Men',
#  'Sneakers For Men',
#  'Kzaara Sneakers Casual Canvas shoes | Branded Stylish O...',
#  'Premium Sports Shoes for Men Sneakers For Men',
# ...

# %%
# scrapping Prices for the sneakers
Prices5=[]

start=0
end=3
for page in range(start,end):
    Price5=driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]')
    for i in Price5[0:100]:
        Prices5.append(i.text)

Prices5
# Out:
# ['₹945',
#  '₹399',
#  '₹199',
#  '₹282',
#  '₹219',
#  '₹1,979',
#  '₹434',
#  '₹299',
#  '₹1,047',
#  '₹219',
#  '₹1,319',
#  '₹589',
#  '₹1,199',
#  '₹1,639',
#  '₹199',
#  '₹489',
#  '₹449',
#  '₹449',
#  '₹1,393',
#  '₹382',
#  '₹399',
#  '₹219',
#  '₹369',
#  '₹599',
#  '₹1,979',
#  '₹824',
#  '₹449',
#  '₹945',
#  '₹399',
#  '₹429',
#  '₹1,434',
#  '₹599',
#  '₹449',
#  '₹1,434',
#  '₹1,349',
#  '₹599',
#  '₹2,459',
#  '₹469',
#  '₹1,639',
#  '₹376',
#  '₹945',
#  '₹399',
#  '₹199',
#  '₹282',
#  '₹219',
#  '₹1,979',
#  '₹434',
#  '₹299',
#  '₹1,047',
#  '₹219',
#  '₹1,319',
#  '₹589',
#  '₹1,199',
#  '₹1,639',
#  '₹199',
#  '₹489',
#  '₹449',
#  '₹449',
#  '₹1,393',
#  '₹382',
#  '₹399',
#  '₹219',
#  '₹369',
#  '₹599',
#  '₹1,979',
#  '₹824',
#  '₹449',
#  '₹945',
#  '₹399',
#  '₹429',
#  '₹1,434',
#  '₹599',
#  '₹449',
#  '₹1,434',
#  '₹1,349',
#  '₹599',
#  '₹2,459',
#  '₹469',
#  '₹1,639',
#  '₹376',
#  '₹945',
#  '₹399',
#  '₹199',
#  '₹282',
#  '₹219',
#  '₹1,979',
# ...

# %%
print(len(Brand_Name5[0:100]), len(Product_description5[0:100]), len(Prices5[0:100]))
# Out:
# 100 100 100

# %%
# creating Data Frame for sneakers

df=pd.DataFrame({'Brand':Brand_Name5[0:100], 'Product':Product_description5[0:100], 'Price':Prices5[0:100]})
df
# Out:
#                   Brand                                            Product  \
# 0              RapidBox  2006 Trenddy Fashion Sporty Casuals Sneakers R...
# 1                   SFR  5011-Latest Collection Stylish & Trendy Casual...
# 2   World Wear Footwear  Mesh |Lightweight|Comfort|Summer|Trendy|Walkin...
# 3                  aadi                                   Sneakers For Men
# 4                Kzaara                     STREET ICON M Sneakers For Men
# ..                  ...                                                ...
# 95               Layasa      Premium Sports Shoes for Men Sneakers For Men
# 96               Layasa             2 Combo Sneaker Shoes Sneakers For Men
# 97          Asian Shoes                     STREET ICON M Sneakers For Men
# 98                 PUMA                            SM-671 Sneakers For Men
# 99               BRUTON                                 Sneakers For Women
#
#      Price
# 0     ₹945
# 1     ₹399
# 2     ₹199
# 3     ₹282
# ...

# %% [markdown]
# # Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7” as shown in the below image:

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
# lets connect to the web driver first
driver=webdriver.Chrome(r"C:\Users\Vikram19c\Downloads\chromedriver.exe")

# %%
#opening the Amazon page on automated chrome browser
driver.get(' https://www.amazon.in')

# %%
# entering product name Laptop

product=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
product.send_keys('Laptops')

# %%
# entering search button

search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span')
search.click()

# %%
Title6=[]
Ratings6=[]
Price6=[]

# %%
Title6=[]

Title_laptop=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
for i in Title_laptop[0:10]:
    Title6.append(i.text)

Title6
# Out:
# ['HP Chromebook 11a, MediaTek MT8183 Processor 11.6 inch(29.5 cm) Thin and Light Touchscreen Laptop (4 GB RAM/64 GB eMMC/ Chrome OS /Fast Charge/Google Assistant/Indigo Blue/1.07Kg), na0002MU, 1.07Kg',
#  'Dell Inspiron 3511 Windows 11 Laptop, Intel i3-1115G4, 8GB DDR4 & 512GB SSD, Win 11 + MSO\'21, 15.6" (39.62Cms) FHD WVA AG, Carbon Black - D560801WIN9B, 1.8Kgs',
#  'HP 15s, AMD Athlon Silver 3050U 8GB RAM/512GB SSD 15.6-inches/39.6 cm HD, Micro-Edge Display/Windows 11/AMD Radeon Graphics/Dual Speakers/MSO/Fast Charge/1.69 Kg, 15s-eq1559AU',
#  'HP 255 G8 Business Laptop with AMD Athlon Silver 3050U APU/ 8GB Ram/ 1TB HDD/ Windows 11/AMD Radeon Vega 8 Mobile Graphics/39.6 cm HD (1366 x 768), SVA , Anti-Glare WLED/Black/1 Year Onsite Warranty',
#  'ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) HD, Dual Core Intel Celeron N4020, Thin and Light Laptop (4GB RAM/256GB SSD/Integrated Graphics/Windows 11 Home/Transparent Silver/1.8 Kg), X515MA-BR011W',
# ...

# %%
rating=driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]')

Rating=[i.text for i in rating[0:5]]
Rating1=[i.text for i in rating[13:18]]
Rating=Rating+Rating1

Rating
# Out:
# ['248', '28', '116', '6', '808', '5', '308', '77', '15', '394']

# %%
Price6=[]
Price_laptop=driver.find_elements(By.XPATH, '//span[@class="a-price-whole"]')
for i in Price_laptop[0:10]:
    Price6.append(i.text)

Price6
# Out:
# ['25,990',
#  '28,990',
#  '25,819',
#  '18,999',
#  '40,990',
#  '28,990',
#  '26,999',
#  '24,990',
#  '99,990',
#  '1,94,900']

# %%
print(len(Title6), len( Rating), len(Price6))
# Out:
# 10 10 10

# %%
# creating Data Frame for Laptops

df=pd.DataFrame({'Title':Title6, 'Ratings':Rating, 'Price':Price6})
df
# Out:
#                                                Title Ratings     Price
# 0  HP Chromebook 11a, MediaTek MT8183 Processor 1...     248    25,990
# 1  Dell Inspiron 3511 Windows 11 Laptop, Intel i3...      28    28,990
# 2  HP 15s, AMD Athlon Silver 3050U 8GB RAM/512GB ...     116    25,819
# 3  HP 255 G8 Business Laptop with AMD Athlon Silv...       6    18,999
# 4  ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) ...     808    40,990
# 5  2021 Apple MacBook Pro (14-inch/35.97 cm, Appl...       5    28,990
# 6  Lenovo Yoga Slim 7 Carbon 11th Gen Intel Core ...     308    26,999
# 7                                                         77    24,990
# 8                                                         15    99,990
# 9  Lenovo IdeaPad Slim 5 AMD Ryzen 7 5700U 15.6"(...     394  1,94,900

# %% [markdown]
# # Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
# lets connect to the web driver first
driver=webdriver.Chrome(r"C:\Users\Vikram19c\Downloads\chromedriver.exe")

# %%
#opening theazquotes on automated chrome browser
driver.get('https://www.azquotes.com/')

# %%
# entering Top Quotes Tag

Top_Quotes=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[2]/div[1]/div/form/input[1]')
Top_Quotes.send_keys('Top Quotes')

# %%
# entering Quotes Tag
Quotes=[]

start=0
end=10
for page in range(start,end):
    Quotes_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in Quotes_tags[0:1000]:
        Quotes.append(i.text)

Quotes
# Out:
# ['The essence of strategy is choosing what not to do.',
#  'One cannot and must not try to erase the past merely because it does not fit the present.',
#  'Patriotism means to stand by the country. It does not mean to stand by the president.',
#  'Death is something inevitable. When a man has done what he considers to be his duty to his people and his country, he can rest in peace. I believe I have made that effort and that is, therefore, why I will sleep for the eternity.',
#  'You have to love a nation that celebrates its independence every July 4, not with a parade of guns, tanks, and soldiers who file by the White House in a show of strength and muscle, but with family picnics where kids throw Frisbees, the potato salad gets iffy, and the flies die from happiness. You may think you have overeaten, but it is patriotism.',
# ...

# %%
# entering Author Tag
Author=[]

start=0
end=10
for page in range(start,end):
    Author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
    for i in Author_tags[0:1000]:
        Author.append(i.text)

Author
# Out:
# ['Michael Porter',
#  'Golda Meir',
#  'Theodore Roosevelt',
#  'Nelson Mandela',
#  'Erma Bombeck',
#  'John Wooden',
#  'Albert Einstein',
#  'Frank Zappa',
#  'William Faulkner',
#  'Will Rogers',
#  'Jimmy Carter',
#  'Albert Einstein',
#  'Abraham Lincoln',
#  'Steven Weinberg',
#  'Franklin D. Roosevelt',
#  'Albert Einstein',
#  'Maya Angelou',
#  'Mark Twain',
#  'Theodore Roosevelt',
#  'Michael Jackson',
#  'Martin Luther King, Jr.',
#  'C. S. Lewis',
#  'Theodore Roosevelt',
#  'Mark Twain',
#  'Abraham Lincoln',
#  'Ruth Graham',
#  'C. S. Lewis',
#  'Groucho Marx',
#  'John Lennon',
#  'Barbara Bush',
#  'Albert Einstein',
#  'Francis Chan',
#  'Henry Ford',
#  'Victor Hugo',
#  'Abu Bakr',
#  'Zig Ziglar',
#  'Winston Churchill',
#  'Zig Ziglar',
#  'John F. Kennedy',
#  'Dwight D. Eisenhower',
#  'Winston Churchill',
#  'Albert Einstein',
#  'Willie Nelson',
#  'Johnny Cash',
#  'Marie Curie',
#  'Maya Angelou',
#  'Amy Bloom',
#  'Zig Ziglar',
#  'John Lennon',
# ...

# %%
# entering Quotes Types Tag
TypesQuotes=[]

start=0
end=10
for page in range(start,end):
    Types_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in Types_tags[0:1000]:
        TypesQuotes.append(i.text)

TypesQuotes
# Out:
# ['Essence, Deep Thought, Transcendentalism',
#  'Inspiration, Past, Trying',
#  'Country, Peace, War',
#  'Inspirational, Motivational, Death',
#  '4th Of July, Food, Patriotic',
#  'Inspirational, Success, Basketball',
#  'Strong, Revenge, Intelligent',
#  'Inspirational, Teacher, Religious',
#  'Truth, Honesty, Lying',
#  'Funny, Reading, Learning',
#  'Strong, Thoughtful, Compassion',
#  'Love, Funny, Life',
#  'Freedom, Men, Democracies Have',
#  'God, Religious, Atheist',
#  'Respect, Kindness, Character',
#  'Inspirational, Motivational, Change',
#  'Inspirational, Life, Inspiring',
#  'Love, Inspirational, Life',
#  'Inspiring, Country, 4th Of July',
#  'Inspirational, Dream, Hate',
#  'Love, Inspirational, Life',
#  'Forgiveness, God, Christian',
#  'Country, Men, Squares',
#  'Inspirational, Relationship, Positive',
#  'Inspirational, Motivational, Positive',
#  'Love, Friendship, Relationship',
#  'Faith, God, Christian',
#  'Art, Freedom, Political Will',
# ...

# %%
print(len(Quotes), len( Author), len(TypesQuotes))
# Out:
# 1000 1000 1000

# %%
# creating Data Frame for Laptops

df=pd.DataFrame({'Quotes':Quotes, 'Author Name':Author, 'Quote Type':TypesQuotes})
df
# Out:
#                                                 Quotes           Author Name  \
# 0    The essence of strategy is choosing what not t...        Michael Porter
# 1    One cannot and must not try to erase the past ...            Golda Meir
# 2    Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...        Nelson Mandela
# 4    You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                 ...                   ...
# 995     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 996  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 997  If you think you are too small to make a diffe...            Dalai Lama
# 998  God doesn't require us to succeed, he only req...         Mother Teresa
# 999    Change your thoughts and you change your world.  Norman Vincent Peale
#
# ...

# %% [markdown]
# # Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
# lets connect to the web driver first
driver=webdriver.Chrome(r"C:\Users\Vikram19c\Downloads\chromedriver.exe")

# %%
#opening the jagronjosh on automated chrome browser
driver.get('https://www.jagranjosh.com')

# %%
# entering GK tag

website=driver.find_element(By.XPATH,'/html/body/div/div[1]/div/div[1]/div/div[5]/div/div/div/form/div[2]/div/input[1]')
website.send_keys('GK')

# %%
# entering search Tag

Search=driver.find_element(By.XPATH,'/html/body/div/div[1]/div/div[1]/div/div[5]/div/div/div/form/div[2]/div/input[1]')
Search.click()

# %%
# entering Prime Ministers of India tag

PrimeMinisters=driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
PrimeMinisters.click()

# %%
# Entering Name tag
Name=[]
names = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
for name in names:
    Name.append(name.text)
    
Name
# Out:
# ['Jawahar Lal Nehru',
#  'Gulzarilal Nanda (Acting)',
#  'Lal Bahadur Shastri',
#  'Gulzari Lal Nanda  (Acting)',
#  'Indira Gandhi',
#  'Morarji Desai',
#  'Charan Singh',
#  'Indira Gandhi',
#  'Rajiv Gandhi',
#  'V. P. Singh',
#  'Chandra Shekhar',
#  'P. V. Narasimha Rao',
#  'Atal Bihari Vajpayee',
#  'H. D. Deve Gowda',
#  'Inder Kumar Gujral',
#  'Atal Bihari Vajpayee',
#  'Manmohan Singh',
#  'Narendra Modi']

# %%
# Entering Born-Dead tag

Born=[]
BD=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for i in BD:
    Born.append(i.text)

Born
# Out:
# ['(1889–1964)',
#  '(1898-1998)',
#  '(1904–1966)',
#  '(1898-1998)',
#  '(1917–1984)',
#  '(1896–1995)',
#  '(1902–1987)',
#  '(1917–1984)',
#  '(1944–1991)',
#  '(1931–2008)',
#  '(1927–2007)',
#  '(1921–2004)',
#  '(1924- 2018)',
#  '(born 1933)',
#  '(1919–2012)',
#  '(1924-2018)',
#  '(born 1932)',
#  '(born 1950)']

# %%
# Entering Term of Office tag

Office=[]
Term=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]/p')
for i in Term:
    Office.append(i.text)

Office
# Out:
# ['15 August 1947 to 27 May 1964',
#  '16 years, 286 days',
#  '27 May 1964 to 9 June 1964,',
#  '13 days',
#  '9 June 1964 to 11 January 1966',
#  '1 year, 216 days',
#  '11 January 1966 to 24 January 1966',
#  '13 days',
#  '24 January 1966 to 24 March 1977',
#  '11 years, 59 days',
#  '24 March 1977 to  28 July 1979 ',
#  '2 year, 126 days',
#  '28 July 1979 to 14 January 1980',
#  '170 days',
#  '14 January 1980 to 31 October 1984',
#  '4 years, 291 days',
#  '31 October 1984 to 2 December 1989',
#  '5 years, 32 days',
#  '2 December 1989 to 10 November 1990',
#  '343 days',
#  '10 November 1990 to 21 June 1991',
#  '223 days',
#  '21 June 1991 to 16 May 1996',
#  '4 years, 330 days',
#  '16 May 1996 to 1 June 1996',
#  '16 days',
#  '1 June 1996 to 21 April 1997',
#  '324 days',
#  '21 April 1997 to 19 March 1998 ',
#  '332 days',
#  '19 March 1998 to 22 May 2004 ',
#  '6 years, 64 days',
#  '22 May 2004 to 26 May 2014   ',
#  '10 years, 4 days',
#  '26 May 2014 - Present']

# %%
# Entering Remarks tag

Remarks=[]
Remark=driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')
for i in Remark:
    Remarks.append(i.text)

Remarks
# Out:
# ['The first prime minister of India and the longest-serving PM of India, the first to die in office.',
#  'First acting PM of India',
#  "He has given the slogan of 'Jai Jawan Jai Kisan' during the Indo-Pak war of 1965",
#  '-',
#  'First female Prime Minister of India',
#  'Oldest to become PM (81 years old) and first to resign from office',
#  'Only PM who did not face the Parliament',
#  'The first lady who served as PM for the second term',
#  'Youngest to become PM (40 years old)',
#  'First PM to step down after a vote of no confidence',
#  'He belongs to  Samajwadi Janata Party',
#  'First PM from south India',
#  'PM for shortest tenure',
#  'He belongs to  Janata Dal',
#  '------',
#  ' The first non-congress PM who completed a full term as PM',
#  ' First Sikh PM',
#  '4th Prime Minister of India who served two consecutive tenures']

# %%
print(len(Name), len(Born), len(Office[0:18]), len(Remarks))
# Out:
# 18 18 18 18

# %%
# creating Data Frame for Laptops

df=pd.DataFrame({'Prime Minister of India':Name, 'Born-Dead':Born, 'Term of Office':Office[0:18], 'Remark': Remarks})
df
# Out:
#         Prime Minister of India     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                         Term of Office  \
# ...

# %% [markdown]
# # Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name and Price) from https://www.motor1.com/

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
# lets connect to the web driver first
driver=webdriver.Chrome(r"C:\Users\Vikram19c\Downloads\chromedriver.exe")

# %%
#opening the Motor1 on automated chrome browser
driver.get('https://www.motor1.com/')

# %%
Dropdown=driver.find_element(By.XPATH,'/html/body/div[3]/div[2]/div/div/div[1]/div')
Dropdown.click()

# %%
Features=driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[3]/ul/li[5]/button')
Features.click()

# %%
Lists=driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[3]/ul/li[6]/ul/li[1]/a')
Lists.click()

# %%
Cars=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[1]/div[1]/div/div/div[9]/div/div[1]/h3/a')
Cars.click()

# %%
# Entering Car Name tag

Car_Name=[]
car=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in car:
    Car_Name.append(i.text)

Car_Name
# Out:
# ['Drako GTE',
#  'De Tomaso P72',
#  'Ferrari LaFerrari',
#  'Pagani Huayra',
#  'McLaren Elva',
#  'Czinger 21C',
#  'Ferrari Monza',
#  'Gordon Murray T.33',
#  'Koenigsegg Gemera',
#  'Zenvo TSR-S',
#  'Hennessey Venom F5',
#  'Bentley Bacalar',
#  'Hispano Suiza Carmen Boulogne',
#  'Bentley Mulliner Batur',
#  'Deus Vayanne',
#  'SSC Tuatara',
#  'Lotus Evija',
#  'Aston Martin Vulcan',
#  'Delage D12',
#  'McLaren Speedtail',
#  'Rimac Nevera',
#  'Pagani Utopia',
#  'Pininfarina Battista',
#  'Ferrari FXX K Evo',
#  'Gordon Murray T.50',
#  'Lamborghini Countach',
#  'Mercedes-AMG Project One',
#  'Aston Martin Victor',
#  'Hennessey Venom F5 Roadster',
#  'Koenigsegg Jesko',
#  'Aston Martin Valkyrie',
#  'W Motors Lykan Hypersport',
#  'McLaren Solus',
#  'Pagani Huayra Roadster BC',
#  'Bugatti Chiron Pur Sport',
#  'Lamborghini Sian',
#  'Koenigsegg CC850',
#  'Bugatti Chiron Super Sport 300+',
#  'Lamborghini Veneno',
#  'Bugatti Bolide',
#  'Bugatti Mistral',
# ...

# %%
# Entering Price tag

#SME asked to skip this part as relative tag cannot be found.

# %%
# creating Data Frame for Expensive Cars

df=pd.DataFrame({'Name of the most Expensive cars':Car_Name[0:50]})
df
# Out:
#     Name of the most Expensive cars
# 0                         Drako GTE
# 1                     De Tomaso P72
# 2                 Ferrari LaFerrari
# 3                     Pagani Huayra
# 4                      McLaren Elva
# 5                       Czinger 21C
# 6                     Ferrari Monza
# 7                Gordon Murray T.33
# 8                 Koenigsegg Gemera
# 9                       Zenvo TSR-S
# 10               Hennessey Venom F5
# 11                  Bentley Bacalar
# 12    Hispano Suiza Carmen Boulogne
# 13           Bentley Mulliner Batur
# 14                     Deus Vayanne
# 15                      SSC Tuatara
# 16                      Lotus Evija
# 17              Aston Martin Vulcan
# 18                       Delage D12
# 19                McLaren Speedtail
# 20                     Rimac Nevera
# 21                    Pagani Utopia
# 22             Pininfarina Battista
# 23                Ferrari FXX K Evo
# 24               Gordon Murray T.50
# ...
